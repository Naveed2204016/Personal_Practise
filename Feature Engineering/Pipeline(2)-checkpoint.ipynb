# %%
import pickle
import numpy as np
import pandas as pd

# %%
with open('model_pickel','rb') as f:
    clf=pickle.load(f)

# %%
with open('ohe_sex_pickel','rb') as f:
    ohe_sex=pickle.load(f)
with open('ohe_emb_pickel','rb') as f:
    ohe_emb=pickle.load(f)

# %%
test_input = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)
test_input_sex = ohe_sex.transform(test_input[:,1].reshape(1,1))
test_input_embarked = ohe_emb.transform(test_input[:,-1].reshape(1,1))
test_input_age = test_input[:,2].reshape(1,1)
test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embarked),axis=1)
clf.predict(test_input_transformed)
# Out:
# C:\Users\Acer\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 6
#       4 test_input_age = test_input[:,2].reshape(1,1)
#       5 test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embarked),axis=1)
# ----> 6 clf.predict(test_input_transformed)
#
# File ~\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:530, in BaseDecisionTree.predict(self, X, check_input)
#     507 """Predict class or regression value for X.
#     508
#     509 For a classification model, the predicted class for each sample in X is
#    (...)
#     527     The predicted classes, or the predict values.
#     528 """
#     529 check_is_fitted(self)
# ...

# %%
df=pd.read_csv('Titanic-Dataset.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(columns=['PassengerId','Name','Ticket','Cabin'],inplace=True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.drop('Survived',axis=1),df['Survived'],test_size=0.2)

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.feature_selection import SelectKBest,chi2
from sklearn.tree import DecisionTreeClassifier

# %%
tf1=ColumnTransformer(transformers=[('Age imputer',SimpleImputer(),[2]),('Embarked imputer',SimpleImputer(strategy='most_frequent'),[6])],remainder='passthrough' )

# %%
tf2=ColumnTransformer(transformers=[('ohe sex embarked',OneHotEncoder(sparse_output=False,handle_unknown='ignore'),[1,6])],remainder='passthrough')

# %%
tf3=ColumnTransformer(transformers=[('scale',MinMaxScaler(),slice(0,10))],remainder='passthrough')

# %%
tf4=SelectKBest(score_func=chi2,k=8)

# %%
tf5=DecisionTreeClassifier()

# %%
pipe=Pipeline([('tf1',tf1),('tf2',tf2),('tf3',tf3),('tf4',tf4),('tf5',tf5)])

# %%
pipe=make_pipeline(tf1,tf2,tf3,tf4,tf5)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer-1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('impute_age', SimpleImputer(),
#                                                   [2]),
#                                                  ('impute_embarked',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   [6])])),
#                 ('columntransformer-2',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe_sex_embarked',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   [1, 6])])),
#                 ('columntransformer-3',
# ...

# %%
x_train
# Out:
#      Pclass     Sex    Age  SibSp  Parch      Fare Embarked
# 469       3  female   0.75      2      1   19.2583        C
# 522       3    male    NaN      0      0    7.2250        C
# 92        1    male  46.00      1      0   61.1750        S
# 836       3    male  21.00      0      0    8.6625        S
# 274       3  female    NaN      0      0    7.7500        Q
# ..      ...     ...    ...    ...    ...       ...      ...
# 752       3    male  33.00      0      0    9.5000        S
# 150       2    male  51.00      0      0   12.5250        S
# 605       3    male  36.00      1      0   15.5500        S
# 487       1    male  58.00      0      0   29.7000        C
# 337       1  female  41.00      0      0  134.5000        C
#
# [712 rows x 7 columns]

# %%
pipe.named_steps
# Out:
# {'columntransformer-1': ColumnTransformer(remainder='passthrough',
#                    transformers=[('impute_age', SimpleImputer(), [2]),
#                                  ('impute_embarked',
#                                   SimpleImputer(strategy='most_frequent'),
#                                   [6])]),
#  'columntransformer-2': ColumnTransformer(remainder='passthrough',
#                    transformers=[('ohe_sex_embarked',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse_output=False),
#                                   [1, 6])]),
#  'columntransformer-3': ColumnTransformer(transformers=[('scale', MinMaxScaler(), slice(0, 10, None))]),
#  'selectkbest': SelectKBest(k=8, score_func=<function chi2 at 0x00000235EA954900>),
#  'decisiontreeclassifier': DecisionTreeClassifier()}

# %%
from sklearn import set_config
set_config(display='diagram')

# %%
y_pred=pipe.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6256983240223464

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(pipe,x_train,y_train,cv=5,scoring='accuracy').mean()
# Out:
# 0.6389934009652319

# %%
params = {
    'decisiontreeclassifier__max_depth':[1,2,3,4,5,None]
}

# %%
from sklearn.model_selection import GridSearchCV
grid=GridSearchCV(pipe,params,cv=5,scoring='accuracy')
grid.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer-1',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('impute_age',
#                                                                          SimpleImputer(),
#                                                                          [2]),
#                                                                         ('impute_embarked',
#                                                                          SimpleImputer(strategy='most_frequent'),
#                                                                          [6])])),
#                                        ('columntransformer-2',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ohe_sex_embarked',
# ...

# %%
grid.best_score_
# Out:
# 0.6389934009652319

# %%
grid.best_params_
# Out:
# {'decisiontreeclassifier__max_depth': 2}

# %%
with open('pipeline.pkl','wb') as f:
    pickle.dump(pipe,f)
