# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('wine_data.csv',header=None,usecols=[0,1,2])
df.columns=['Class label', 'Alcohol', 'Malic acid']
df
# Out:
#      Class label  Alcohol  Malic acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
sns.kdeplot(df['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(df['Malic acid'])
# Out:
# <Axes: xlabel='Malic acid', ylabel='Density'>

# %%
color_dict={1:'red',3:'green',2:'blue'}
sns.scatterplot(data=df,x='Alcohol',y='Malic acid',hue=df['Class label'],palette=color_dict)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic acid'>

# %%
from sklearn.model_selection import train_test_split
X=df.drop('Class label',axis=1)
Y=df.drop(['Alcohol', 'Malic acid'],axis=1)
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3)

# %%
from sklearn.preprocessing import MinMaxScaler
ob1=MinMaxScaler()
ob1.fit(x_train)
x_train_n=ob1.transform(x_train)
x_test_n=ob1.transform(x_test)

# %%
x_train_n=pd.DataFrame(x_train_n,columns=x_train.columns)
x_test_n=pd.DataFrame(x_test_n,columns=x_train.columns)

# %%
np.round(x_train.describe(),1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean      13.0         2.4
# std        0.8         1.1
# min       11.0         0.9
# 25%       12.3         1.6
# 50%       12.9         1.9
# 75%       13.6         3.1
# max       14.8         5.8

# %%
np.round(x_train_n.describe(),1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean       0.5         0.3
# std        0.2         0.2
# min        0.0         0.0
# 25%        0.3         0.1
# 50%        0.5         0.2
# 75%        0.7         0.4
# max        1.0         1.0

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(x_train['Alcohol'], x_train['Malic acid'])
ax1.set_title("Before Scaling")
ax2.scatter(x_train_n['Alcohol'], x_train_n['Malic acid'])
ax2.set_title("After Scaling")
plt.show()

# %%
ig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(x_train['Alcohol'], ax=ax1)
sns.kdeplot(x_train['Malic acid'], ax=ax1)

# after scaling
ax2.set_title('After Standard Scaling')
sns.kdeplot(x_train_n['Alcohol'], ax=ax2)
sns.kdeplot(x_train_n['Malic acid'], ax=ax2)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Alcohol Distribution Before Scaling')
sns.kdeplot(x_train['Alcohol'], ax=ax1)

# after scaling
ax2.set_title('Alcohol Distribution After Standard Scaling')
sns.kdeplot(x_train_n['Alcohol'], ax=ax2)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Malic Acid Distribution Before Scaling')
sns.kdeplot(x_train['Malic acid'], ax=ax1)

# after scaling
ax2.set_title('Malic Acid Distribution After Standard Scaling')
sns.kdeplot(x_train_n['Malic acid'], ax=ax2)
plt.show()
