# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('placement (2).csv')

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
X=df[['cgpa','placement_exam_marks']]

# %%
Y=df['placed']

# %%
from sklearn.linear_model import Perceptron

# %%
p=Perceptron()
p.fit(X,Y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[-25.65,  -8.  ]])

# %%
p.intercept_
# Out:
# array([-15.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values,Y.values,clf=p,legend=2)
# Out:
# C:\Users\Acer\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
